# %%
'''[(‘중’, 2144),
 (‘기다리다‘, 2189),
 (‘알’, 2216),
 (‘해’, 2218),
 (‘꿈’, 2239),
 (‘오늘‘, 2242),
 (‘아기‘, 2295),
 (‘위’, 2298),
 (‘함께‘, 2333),
 (‘시간‘, 2355),
 (‘돼다‘, 2406),
 (‘아프다‘, 2424),
 (‘젠’, 2442),
 (‘세상‘, 2525),
 (‘모습‘, 2602),
 (‘주다‘, 2642),
 (‘당신‘, 2703),
 (‘가슴‘, 2746),
 (‘지금‘, 2840),
 (‘하나‘, 2848),
 (‘걸’, 2904),
 (‘모두‘, 2939),
 (‘또’, 2941),
 (‘생각‘, 2950),
 (‘니’, 2958),
 (‘넌’, 3006),
 (‘눈’, 3025),
 (‘너무‘, 3034),
 (‘안’, 3082),
 (‘때’, 3106),
 (‘그것‘, 3111),
 (‘맘’, 3135),
 (‘왜’, 3164),
 (‘그만큼‘, 3229),
 (‘떠나다‘, 3238),
 (‘네’, 3307),
 (‘이제‘, 3346),
 (‘좋다‘, 3373),
 (‘속’, 3400),
 (‘다’, 3432),
 (‘다시‘, 3447),
 (‘눈물‘, 3466),
 (‘내다‘, 3500),
 (‘버리다‘, 3582),
 (‘알다‘, 3624),
 (‘밤’, 3632),
 (‘되다‘, 3748),
 (‘그렇다‘, 3790),
 (‘모르다‘, 3831),
 (‘잊다‘, 3868),
 (‘이’, 3887),
 (‘같다‘, 3888),
 (‘사람‘, 4170),
 (‘아니다‘, 4253),
 (‘나르다‘, 4268),
 (‘오’, 4423),
 (‘싶다‘, 4433),
 (‘더’, 4835),
 (‘마음‘, 5017),
 (‘오다‘, 5196),
 (‘가다‘, 5266),
 (‘우리‘, 5461),
 (‘널’, 5542),
 (‘않다‘, 5688),
 (‘난’, 6627),
 (‘수’, 6926),
 (‘것’, 6982),
 (‘날’, 7914),
 (‘그대‘, 7967),
 (‘그’, 8222),
 (‘보다‘, 9236),
 (‘말’, 9379),
 (‘없다‘, 11727),
 (‘있다‘, 13507),
 (‘내’, 14481),
 (‘사랑‘, 19317),
 (‘너’, 24244),
 (‘나’, 25183),
 (‘하다’, 36207)]'''
# Out:
# '[(‘중’, 2144),\n (‘기다리다‘, 2189),\n (‘알’, 2216),\n (‘해’, 2218),\n (‘꿈’, 2239),\n (‘오늘‘, 2242),\n (‘아기‘, 2295),\n (‘위’, 2298),\n (‘함께‘, 2333),\n (‘시간‘, 2355),\n (‘돼다‘, 2406),\n (‘아프다‘, 2424),\n (‘젠’, 2442),\n (‘세상‘, 2525),\n (‘모습‘, 2602),\n (‘주다‘, 2642),\n (‘당신‘, 2703),\n (‘가슴‘, 2746),\n (‘지금‘, 2840),\n (‘하나‘, 2848),\n (‘걸’, 2904),\n (‘모두‘, 2939),\n (‘또’, 2941),\n (‘생각‘, 2950),\n (‘니’, 2958),\n (‘넌’, 3006),\n (‘눈’, 3025),\n (‘너무‘, 3034),\n (‘안’, 3082),\n (‘때’, 3106),\n (‘그것‘, 3111),\n (‘맘’, 3135),\n (‘왜’, 3164),\n (‘그만큼‘, 3229),\n (‘떠나다‘, 3238),\n (‘네’, 3307),\n (‘이제‘, 3346),\n (‘좋다‘, 3373),\n (‘속’, 3400),\n (‘다’, 3432),\n (‘다시‘, 3447),\n (‘눈물‘, 3466),\n (‘내다‘, 3500),\n (‘버리다‘, 3582),\n (‘알다‘, 3624),\n (‘밤’, 3632),\n (‘되다‘, 3748),\n (‘그렇다‘, 3790),\n (‘모르다‘, 3831),\n (‘잊다‘, 3868),\n (‘이’, 3887),\n (‘같다‘, 3888),\n (‘사람‘, 4170),\n (‘아니다‘, 4253),\n (‘나르다‘, 4268),\n (‘오’, 4423),\n (‘싶다‘, 4433),\n (‘더’, 4835),\n (‘마음‘, 5017),\n (‘오다‘, 5196),\n (‘가다‘, 5266),\n (‘우리‘, 5461),\n (‘널’, 5542),\n (
# ...

# %%
first_stopwords_byme = [
'하다', '있다', '없다', '말', '되다', '그렇다', '생각', '걸', '그', '것', '오', 
'이', '다', '속','해', '돼다', '알', '젠', '나르다', '주다', '아기', '중', '사람', 
'오다','가다','않다'
 ]

# %%
meter_list = [3, 7, 9, 10] 
print([100*i for i in meter_list if i%2 != 0])
# Out:
# [300, 700, 900]
