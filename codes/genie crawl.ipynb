# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
import time
from tqdm import tqdm

# %% [markdown]
# 지니 연도별 리스트 가져오기

# %%
url_years, years = [], [] 

url_year = 'https://www.genie.co.kr/chart/musicHistory?year=2021&category=0'

headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
          'referer' : 'https://www.genie.co.kr/chart/musicHistory'}

resp = requests.get(url_year, headers=headers)
soup = BeautifulSoup(resp.content, 'lxml')

a_tags = soup.select('td.info a')
tit_tags = soup.select('td.info a.title')
art_tags = soup.select('td.info a.artist')
id_tags = soup.select('td.info a.title')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-485be6f07f6c> in <module>
#      10
#      11 a_tags = soup.select('td.info a')
# ---> 12 tit_tags = soup.select('td.info a.title',text)
#      13 art_tags = soup.select('td.info a.artist')
#      14 id_tags = soup.select('td.info a.title')
#
# NameError: name 'text' is not defined

# %%
title = tit_tags.find('a',{class:})
# Out:
# [<a class="title ellipsis" href="#" onclick="fnPlaySong('92125854','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                      Celebrity</a>,
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('86992414','1');return false;" title="재생">
#  <span class="icon icon-title">TITLE</span>
#
#
#
#
#
#
#                                      롤린 (Rollin')</a>,
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('90705547','1');return false;" title="재생">
#  <span class="icon icon-title">TITLE</span>
#
#
#
#
#
#
#                                      Dynamite</a>,
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('92749701','1');return false;" title="재생">
#  <span class="icon icon-title">TITLE</span>
#
#
#
#
#
#
#                                      라일락</a>,
#  <a class="title ellipsis" href="#" onclick="fnPlaySong('93330349','1');return false;" title="재생">
#  <span class="icon icon-title">TITLE</span>
#
#
#
#
#
#
# ...

# %%
# Out:
# 85
